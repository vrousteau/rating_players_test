# %%
# import libraries

import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
import os
import dotenv
from datetime import datetime
import itertools

# %%
ENV_FILKEPATH = "C:/Users/vrousteau410/OneDrive - Sporting Solutions/Documents/Work/Profile/Rating_of_players_test"
if os.path.exists(ENV_FILKEPATH + "/.env"):
    dotenv.load_dotenv(ENV_FILKEPATH + "/.env")
    secrets_file_path = os.getenv("BIGQUERY_SECRETS_FILE")
    project_id = os.getenv("BIGQUERY_PROJECT_ID")
else:
    raise FileExistsError("please ensure pointing at a .env file")

if secrets_file_path is None or project_id is None:
    raise ValueError("necessary environment variables missing")

# %%
client = bigquery.Client.from_service_account_json(
    secrets_file_path, project=project_id
)

# %%
# import excel file

df = pd.read_excel("Customer Ratings.xlsx")
df['Date added'] = pd.to_datetime(df['Date added'], format="%d/%m/%Y")
df['formatted_date'] = df['Date added'].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
# Get columns we are interested in 

df = df[['formatted_date','Partner','Acc Number']].dropna().reset_index(drop=True)

# %%
df.Partner.value_counts()
# Out:
# Partner
# Danske    30
# OLG       29
# Spinfo    11
# CSGO       4
# 3et        1
# Name: count, dtype: int64

# %%
# Replace each partners by the name of the table where the data is (for each partner)

df['Partner_table'] = df.Partner.replace({
    'Danske': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
    'OLG': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
    'Spinfo': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
    'CSGO': 'spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed',
    '3et': 'spoke-profile-prod-1.profile_dataset_triplebet.profile_betflow_processed'
    }, regex=True)

# %%
# Get all the information in a list

list_info = []

for i in range(len(df)):
    list_info.append({
        'table': df.Partner_table[i],
        'id_date_pairs': [
            (df['Acc Number'][i], df['formatted_date'][i]),
        ],
    })

# %%
list_info
# Out:
# [{'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4166309, '2023-08-15 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1565061, '2023-08-15 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(926880, '2023-08-15 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25227184', '2023-08-15 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24532052', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25225784', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25019384', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24890114', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24702518', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4296561, '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE146776', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24376169', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25136125', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24825496', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24661558', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4345814, '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE16530277', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25122574', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(3859712, '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1171530, '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE23730520', '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(961170, '2023-08-16 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('KY969', '2023-08-17 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24371022', '2023-08-17 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24375438', '2023-08-17 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4348908, '2023-08-17 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(567928, '2023-08-17 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(896689, '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25291942', '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('LE570', '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('HF823', '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('JK727', '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('KV226', '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed',
#   'id_date_pairs': [(5537001, '2023-08-18 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1512748, '2023-08-20 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1070023, '2023-08-20 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(896910, '2023-08-20 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25004250', '2023-08-20 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('A9675', '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4005891, '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(434, '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4361041, '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(3602145, '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1456613, '2023-08-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('KG148', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('KC821', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('KN559', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('B0583', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25247929', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25215379', '2023-08-23 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25305949', '2023-08-25 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24556484', '2023-08-25 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed',
#   'id_date_pairs': [('A9603', '2023-08-25 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(3863541, '2023-08-29 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(27523, '2023-09-04 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(4339704, '2023-09-04 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed',
#   'id_date_pairs': [(1220611, '2023-09-05 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25225552', '2023-09-06 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(3990387, '2023-09-06 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_triplebet.profile_betflow_processed',
#   'id_date_pairs': [(7258, '2023-09-06 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(807671, '2023-09-06 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24379736', '2023-09-11 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed',
#   'id_date_pairs': [(1453122, '2023-09-13 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24449373', '2023-09-13 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed',
#   'id_date_pairs': [(616945, '2023-09-13 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [('430166\xa0', '2023-09-13 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE24697664', '2023-09-14 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE25291942', '2023-09-14 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(681800, '2023-09-14 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(3812467, '2023-09-19 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE23989242', '2023-09-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(1916, '2023-09-21 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(972610, '2023-09-29 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed',
#   'id_date_pairs': [(961654, '2023-10-06 00:00:00')]},
#  {'table': 'spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed',
#   'id_date_pairs': [('BEDE23826272', '2023-11-01 00:00:00')]}]

# %%
list_query_add = []

for table_info in list_info:
    table_name = table_info['table']
    id_date_pairs = table_info['id_date_pairs']

    sql_query = f"SELECT stakeAmount FROM {table_name} WHERE "
    sql_conditions = []

    for id_value, date_value in id_date_pairs:
        condition = f"customerId = '{id_value}' AND placedAt <= '{date_value}'"
        sql_conditions.append(condition)

    sql_query += " OR ".join(sql_conditions)

    # Print the generated query
    print("Generated SQL Query:", sql_query)

    # Execute the query and fetch the results
    query_job = client.query(sql_query)
    results = query_job.result()

    # Convert results to a list of dictionaries
    results_list = list(results)

    # Append the results to the list
    list_query_add.append(results_list)
# Out:
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4166309' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1565061' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '926880' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25227184' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24532052' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25225784' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25019384' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24890114' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24702518' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4296561' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE146776' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24376169' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25136125' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24825496' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24661558' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4345814' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE16530277' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25122574' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3859712' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1171530' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23730520' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '961170' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KY969' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24371022' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24375438' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4348908' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '567928' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '896689' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25291942' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'LE570' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'HF823' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'JK727' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KV226' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '5537001' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1512748' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1070023' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '896910' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25004250' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'A9675' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4005891' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '434' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4361041' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3602145' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1456613' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KG148' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KC821' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KN559' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'B0583' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25247929' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25215379' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25305949' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24556484' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'A9603' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3863541' AND placedAt <= '2023-08-29 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '27523' AND placedAt <= '2023-09-04 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4339704' AND placedAt <= '2023-09-04 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '1220611' AND placedAt <= '2023-09-05 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25225552' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3990387' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_triplebet.profile_betflow_processed WHERE customerId = '7258' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '807671' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24379736' AND placedAt <= '2023-09-11 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '1453122' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24449373' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '616945' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '430166 ' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24697664' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25291942' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '681800' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3812467' AND placedAt <= '2023-09-19 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23989242' AND placedAt <= '2023-09-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1916' AND placedAt <= '2023-09-21 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '972610' AND placedAt <= '2023-09-29 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '961654' AND placedAt <= '2023-10-06 00:00:00'
# Generated SQL Query: SELECT stakeAmount FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23826272' AND placedAt <= '2023-11-01 00:00:00'

# %%
list_query = []

for table_info in list_info:
    table_name = table_info['table']
    id_date_pairs = table_info['id_date_pairs']

    sql_query = f"SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM {table_name} WHERE "
    sql_conditions = []

    for id_value, date_value in id_date_pairs:
        condition = f"customerId = '{id_value}' AND placedAt <= '{date_value}'"
        sql_conditions.append(condition)

    sql_query += " OR ".join(sql_conditions)

    # Print the generated query
    print("Generated SQL Query:", sql_query)

    # Execute the query and fetch the results
    query_job = client.query(sql_query)
    results = query_job.result()

    # Convert results to a list of dictionaries
    results_list = list(results)

    # Append the results to the list
    list_query.append(results_list)
# Out:
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4166309' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1565061' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '926880' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25227184' AND placedAt <= '2023-08-15 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24532052' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25225784' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25019384' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24890114' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24702518' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4296561' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE146776' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24376169' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25136125' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24825496' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24661558' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4345814' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE16530277' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25122574' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3859712' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1171530' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23730520' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '961170' AND placedAt <= '2023-08-16 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KY969' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24371022' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24375438' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4348908' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '567928' AND placedAt <= '2023-08-17 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '896689' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25291942' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'LE570' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'HF823' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'JK727' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KV226' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '5537001' AND placedAt <= '2023-08-18 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1512748' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1070023' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '896910' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25004250' AND placedAt <= '2023-08-20 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'A9675' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4005891' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '434' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4361041' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3602145' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1456613' AND placedAt <= '2023-08-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KG148' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KC821' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'KN559' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'B0583' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25247929' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25215379' AND placedAt <= '2023-08-23 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25305949' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24556484' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_spinfixedodds.profile_betflow_processed WHERE customerId = 'A9603' AND placedAt <= '2023-08-25 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3863541' AND placedAt <= '2023-08-29 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '27523' AND placedAt <= '2023-09-04 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '4339704' AND placedAt <= '2023-09-04 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '1220611' AND placedAt <= '2023-09-05 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25225552' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3990387' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_triplebet.profile_betflow_processed WHERE customerId = '7258' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '807671' AND placedAt <= '2023-09-06 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24379736' AND placedAt <= '2023-09-11 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '1453122' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24449373' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_csgoempire.profile_betflow_processed WHERE customerId = '616945' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '430166 ' AND placedAt <= '2023-09-13 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE24697664' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE25291942' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '681800' AND placedAt <= '2023-09-14 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '3812467' AND placedAt <= '2023-09-19 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23989242' AND placedAt <= '2023-09-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '1916' AND placedAt <= '2023-09-21 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '972610' AND placedAt <= '2023-09-29 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_danskespil.profile_betflow_processed WHERE customerId = '961654' AND placedAt <= '2023-10-06 00:00:00'
# Generated SQL Query: SELECT customerId, betVariety, eventSport, result, SP, placedAt, betId, price, potentialSwing, winnings FROM spoke-profile-prod-1.profile_dataset_olg.profile_betflow_processed WHERE customerId = 'BEDE23826272' AND placedAt <= '2023-11-01 00:00:00'

# %%
import itertools

# %%
column_names = [
    'customerId',
    'betVariety',
    'eventSport',
    'result',
    'SP',
    'placedAt',
    'betId',
    'price',
    'potentialSwing',
    'winnings'
]

# %%
merge_data_test_customers = list(
    itertools.chain(*list_query)
)

# Create dataframe with all bets from the 2 partners

df_all_bet_test_customers = pd.DataFrame.from_records(
    merge_data_test_customers
)

df_all_bet_test_customers.columns = pd.Index(column_names)

# %%
column_names_add = [
    'stakeAmount'
]

# %%
merge_data_test_customers_add = list(
    itertools.chain(*list_query_add)
)

# Create dataframe with all bets from the 2 partners

df_all_bet_test_customers_stakeAmount = pd.DataFrame.from_records(
    merge_data_test_customers_add
)

df_all_bet_test_customers_stakeAmount.columns = pd.Index(column_names_add)

# %%
df_all_bet_test_customers_stakeAmount
# Out:
#        stakeAmount
# 0            10000
# 1             1000
# 2             1000
# 3             1000
# 4             1000
# ...            ...
# 121713         225
# 121714         450
# 121715         225
# 121716        1750
# 121717         394
#
# [121718 rows x 1 columns]

# %%
merged_df = pd.read_csv('test_customers_bet_data_v2.csv')

# %%
merged_df['stakeAmount'] = df_all_bet_test_customers_stakeAmount['stakeAmount']

# %%
df_partner_account = df[['Acc Number','Partner']]

# %%
df_partner_account['Acc Number'] = df_partner_account['Acc Number'].astype(str)
# Out:
# C:\Users\vrousteau410\AppData\Local\Temp\ipykernel_8832\528818826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_partner_account['Acc Number'] = df_partner_account['Acc Number'].astype(str)

# %%
merged_df = pd.merge(df_all_bet_test_customers, df_partner_account, left_on='customerId', right_on='Acc Number', how='left')

# %%
merged_df = merged_df.drop(columns= 'Acc Number')

# %%
merged_df.to_csv('test_customers_bet_data_v2.csv')

# %%
why0_potentialSwing = merged_df[merged_df.potentialSwing == 0].reset_index(drop = True)

# %%
why0_potentialSwing.Partner.value_counts()
# Out:
# Partner
# OLG       18466
# Spinfo     1933
# Name: count, dtype: int64

# %%
why0_potentialSwing[why0_potentialSwing.Partner == 'Spinfo']
# Out:
#      customerId betVariety    eventSport result         SP  \
# 7193      KV226   MULTIPLE  HORSE_RACING   LOSS  34.327250
# 7194      KV226   MULTIPLE  HORSE_RACING   LOSS   4.038500
# 7195      KV226   MULTIPLE  HORSE_RACING   LOSS  75.519950
# 7196      KV226     SINGLE  HORSE_RACING   LOSS   2.157165
# 7197      KV226   MULTIPLE  HORSE_RACING   LOSS  20.625000
# ...         ...        ...           ...    ...        ...
# 9628      B0583     SINGLE  HORSE_RACING   LOSS  19.000000
# 9629      B0583     SINGLE  HORSE_RACING   LOSS  12.000000
# 9630      B0583     SINGLE  HORSE_RACING    WIN  21.000000
# 9631      B0583     SINGLE  HORSE_RACING   LOSS   2.100000
# 9632      B0583     SINGLE  HORSE_RACING   LOSS   2.880000
#
#                        placedAt    betId     price  potentialSwing  winnings  \
# 7193  2022-12-17 16:36:31+00:00  8364107  34.32725             0.0       0.0
# 7194  2022-12-17 16:31:22+00:00  8364102   4.03850             0.0       0.0
# 7195  2022-12-17 16:39:53+00:00  8364116  75.51995             0.0       0.0
# 7196  2022-12-17 17:00:57+00:00  8364134   2.00000             0.0       0.0
# 7197  2023-01-28 16:36:18+00:00  8418561  20.62500             0.0       0.0
# ...                         ...      ...       ...             ...       ...
# 9628  2021-06-17 17:13:20+00:00  7210784  19.00000             0.0       0.0
# 9629  2021-06-17 16:35:50+00:00  7210572  12.00000             0.0       0.0
# 9630  2021-06-17 17:14:07+00:00  7210785  21.00000             0.0    2600.0
# 9631  2022-03-31 11:59:29+00:00  7847372   2.10000             0.0       0.0
# 9632  2022-03-31 13:04:43+00:00  7847447   2.88000             0.0       0.0
#
#      Partner
# 7193  Spinfo
# 7194  Spinfo
# 7195  Spinfo
# 7196  Spinfo
# 7197  Spinfo
# ...      ...
# 9628  Spinfo
# 9629  Spinfo
# 9630  Spinfo
# 9631  Spinfo
# 9632  Spinfo
#
# [1933 rows x 11 columns]

# %%
one_customer_df = df_all_bet_test_customers[df_all_bet_test_customers.customerId == '4345814'].reset_index(drop = True)
one_customer_df.potentialSwing.value_counts()
# Out:
# potentialSwing
# 6000.0    18
# 8500.0    17
# 7500.0    13
# 4800.0    12
# 8000.0    12
#           ..
# 295.5      1
# 4290.0     1
# 2860.0     1
# 2750.0     1
# 2650.0     1
# Name: count, Length: 545, dtype: int64

# %%
one_customer_df['stake'] = one_customer_df['potentialSwing'] / one_customer_df['price']

# %%
total_stake = one_customer_df.stake.sum()

# %%
total_stake
# Out:
# 1874558.1087351216

# %%
total_win =one_customer_df.winnings.sum()

# %%
total_win-total_stake
# Out:
# 90062.65126487869

# %%
one_customer_df
# Out:
#       Unnamed: 0 customerId betVariety eventSport      result      SP  \
# 0          14702    4345814     SINGLE     TENNIS        LOSS  100.00
# 1          14703    4345814     SINGLE   FOOTBALL        LOSS   23.00
# 2          14704    4345814     SINGLE   FOOTBALL  CASHED_OUT   60.00
# 3          14705    4345814     SINGLE   FOOTBALL  CASHED_OUT    2.20
# 4          14706    4345814     SINGLE     TENNIS         WIN    1.72
# ...          ...        ...        ...        ...         ...     ...
# 1226       15928    4345814     SINGLE     TENNIS        LOSS    2.65
# 1227       15929    4345814     SINGLE   FOOTBALL        LOSS   19.00
# 1228       15930    4345814     SINGLE   FOOTBALL        LOSS    9.00
# 1229       15931    4345814     SINGLE     TENNIS  CASHED_OUT    4.30
# 1230       15932    4345814     SINGLE   FOOTBALL  CASHED_OUT    2.85
#
#                               placedAt      betId   price  potentialSwing  \
# 0     2023-07-04 18:14:17.450000+00:00  484897843  100.00         20000.0
# 1     2023-07-04 17:47:34.163000+00:00  484897497   23.00         11500.0
# 2     2023-07-04 17:43:48.290000+00:00  484896941   60.00         18000.0
# 3     2023-07-04 16:49:36.210000+00:00  484892516    2.20          6600.0
# 4     2023-07-04 21:52:39.302000+00:00  484910114    1.72          2580.0
# ...                                ...        ...     ...             ...
# 1226  2023-08-03 14:08:58.309000+00:00  487565035    2.65          2650.0
# 1227  2023-08-03 12:05:10.138000+00:00  487565588   19.00         19000.0
# 1228  2023-08-03 18:04:37.547000+00:00  487612429    9.00          9000.0
# 1229  2023-08-03 13:59:11.460000+00:00  487577648    4.30         12900.0
# 1230  2023-08-03 19:10:33.898000+00:00  487612828    2.85          2850.0
#
#       winnings Partner   stake
# 0         0.00  Danske   200.0
# 1         0.00  Danske   500.0
# 2       110.40  Danske   300.0
# 3      3113.85  Danske  3000.0
# 4      2580.00  Danske  1500.0
# ...        ...     ...     ...
# 1226      0.00  Danske  1000.0
# 1227      0.00  Danske  1000.0
# 1228      0.00  Danske  1000.0
# 1229   1551.37  Danske  3000.0
# 1230     47.67  Danske  1000.0
#
# [1231 rows x 13 columns]
